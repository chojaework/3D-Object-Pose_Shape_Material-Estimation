# %%
# !python evaluation.py \
                      --log_name evallog \
                      --ckpt_name evallog \
                      --dataset CategoryDataset \
                      --root /scannet/ShapeNetCore.v2.PC15k \
                      --resume ./ckpts/cat_pose_id_01_FCGF16 \
                      --trainer RetrievalTrainer \
                      --embedding identity \
                      --dim 1024 512 256 \
                      --voxel_size 0.03 \
                      --catid 03001627 \
                      --batch_size 32 \
                      --model_n_out 16 \
                      --conv1_kernel_size 3 \
                      --pos_ratio 0.1 \
                      --neg_ratio 0.50 \
                      --train_pose \
                      --use_symmetry \
                      --mode val
# Out:
# True
# 2021-03-19 00:06:10 cuda
# 2021-03-19 00:06:10 trainer: RetrievalTrainer
# 2021-03-19 00:06:10 mode: val
# 2021-03-19 00:06:10 category ID: 03001627
# 2021-03-19 00:06:10 dataset: CategoryDataset, batch_size: 32
# 2021-03-19 00:06:10 embedding dim: [1024, 512, 256]
# 2021-03-19 00:06:10 voxel size: 0.03
# 2021-03-19 00:06:10 optimizer: SGD learning rate: 0.1, exp_gamma: 0.99
# 2021-03-19 00:06:10 embedding: identity
# 2021-03-19 00:06:10 pos ratio: 0.1, neg ratio: 0.5
# 2021-03-19 00:06:10 train_pose: True, train_ret: False
# 2021-03-19 00:06:10 resume: ./ckpts/cat_pose_id_01_FCGF16
# 2021-03-19 00:06:10 pretrain:
# 2021-03-19 00:06:10 CatId: 03001627
# 2021-03-19 00:06:10 pos ratio: 0.1 neg ratio: 0.5
# 100%|████████████████████████████████████████| 662/662 [00:04<00:00, 139.90it/s]
# 593
# 592
# 2021-03-19 00:06:15 Finish Loading
# 2021-03-19 00:06:18 Using optimizer SGD
# 2021-03-19 00:06:18 loading checkpoint from ./ckpts/cat_pose_id_01_FCGF16
# start eval
# ...

# %%
# !python evaluation.py \
                      --log_name evallog \
                      --ckpt_name evallog \
                      --dataset CategoryDataset \
                      --root /scannet/ShapeNetCore.v2.PC15k \
                      --resume ./ckpts/cat_table_pose_id_01_FCGF16 \
                      --trainer RetrievalTrainer \
                      --embedding identity \
                      --dim 1024 512 256 \
                      --voxel_size 0.03 \
                      --catid 04379243 \
                      --batch_size 32 \
                      --model_n_out 16 \
                      --conv1_kernel_size 3 \
                      --pos_ratio 0.10 \
                      --neg_ratio 0.50 \
                      --train_pose \
                      --mode test
# Out:
# False
# 2021-02-26 19:01:13 cuda
# 2021-02-26 19:01:13 trainer: RetrievalTrainer
# 2021-02-26 19:01:13 mode: test
# 2021-02-26 19:01:13 category ID: 04379243
# 2021-02-26 19:01:13 dataset: CategoryDataset, batch_size: 32
# 2021-02-26 19:01:13 embedding dim: [1024, 512, 256]
# 2021-02-26 19:01:13 voxel size: 0.03
# 2021-02-26 19:01:13 optimizer: SGD learning rate: 0.1, exp_gamma: 0.99
# 2021-02-26 19:01:13 embedding: identity
# 2021-02-26 19:01:13 pos ratio: 0.1, neg ratio: 0.5
# 2021-02-26 19:01:13 train_pose: True, train_ret: False
# 2021-02-26 19:01:13 resume: ./ckpts/cat_table_pose_id_01_FCGF16
# 2021-02-26 19:01:13 pretrain:
# 2021-02-26 19:01:13 CatId: 04379243
# 2021-02-26 19:01:13 pos ratio: 0.1 neg ratio: 0.5
# 100%|██████████████████████████████████████| 1679/1679 [00:01<00:00, 876.81it/s]
# 1569
# 1559
# 1557
# 2021-02-26 19:01:16 Finish Loading
# 2021-02-26 19:01:18 Using optimizer SGD
# 2021-02-26 19:01:18 loading checkpoint from ./ckpts/cat_table_pose_id_01_FCGF16
# ...

# %%
# !python evaluation.py \
                      --log_name evallog \
                      --ckpt_name evallog \
                      --dataset CategoryDataset \
                      --root /scannet/ShapeNetCore.v2.PC15k \
                      --resume ./ckpts/cat_table_ret_conv_max_fc_01 \
                      --trainer RetrievalTrainer \
                      --embedding conv1_max_embedding \
                      --dim 1024 512 256 \
                      --voxel_size 0.03 \
                      --catid 04379243 \
                      --batch_size 32 \
                      --model_n_out 16 \
                      --conv1_kernel_size 3 \
                      --pos_ratio 0.10 \
                      --neg_ratio 0.50 \
                      --train_ret \
                      --mode test
# Out:
# False
# 2021-02-26 17:11:04 cuda
# 2021-02-26 17:11:04 trainer: RetrievalTrainer
# 2021-02-26 17:11:04 mode: test
# 2021-02-26 17:11:04 category ID: 04379243
# 2021-02-26 17:11:04 dataset: CategoryDataset, batch_size: 32
# 2021-02-26 17:11:04 embedding dim: [1024, 512, 256]
# 2021-02-26 17:11:04 voxel size: 0.03
# 2021-02-26 17:11:04 optimizer: SGD learning rate: 0.1, exp_gamma: 0.99
# 2021-02-26 17:11:04 embedding: conv1_max_embedding
# 2021-02-26 17:11:04 pos ratio: 0.1, neg ratio: 0.5
# 2021-02-26 17:11:04 train_pose: False, train_ret: True
# 2021-02-26 17:11:04 resume: ./ckpts/cat_table_ret_conv_max_fc_01
# 2021-02-26 17:11:04 pretrain:
# 2021-02-26 17:11:04 CatId: 04379243
# 2021-02-26 17:11:04 pos ratio: 0.1 neg ratio: 0.5
# 100%|██████████████████████████████████████| 1679/1679 [00:16<00:00, 101.31it/s]
# 1569
# 1559
# 1557
# 2021-02-26 17:11:22 Finish Loading
# 2021-02-26 17:11:24 Using optimizer SGD
# ...

# %%
# !python evaluation.py \
                      --log_name evallog \
                      --ckpt_name evallog \
                      --dataset CategoryDataset \
                      --root /scannet/ShapeNetCore.v2.PC15k \
                      --resume ./ckpts/cat_table_ret_conv_fc \
                      --trainer RetrievalTrainer \
                      --embedding conv1_fc \
                      --dim 1024 512 256 \
                      --voxel_size 0.03 \
                      --catid 04379243 \
                      --batch_size 32 \
                      --model_n_out 16 \
                      --conv1_kernel_size 3 \
                      --pos_ratio 0.10 \
                      --neg_ratio 0.50 \
                      --train_ret \
                      --mode test
# Out:
# False
# 2021-02-26 17:23:49 cuda
# 2021-02-26 17:23:49 trainer: RetrievalTrainer
# 2021-02-26 17:23:49 mode: test
# 2021-02-26 17:23:49 category ID: 04379243
# 2021-02-26 17:23:49 dataset: CategoryDataset, batch_size: 32
# 2021-02-26 17:23:49 embedding dim: [1024, 512, 256]
# 2021-02-26 17:23:49 voxel size: 0.03
# 2021-02-26 17:23:49 optimizer: SGD learning rate: 0.1, exp_gamma: 0.99
# 2021-02-26 17:23:49 embedding: conv1_fc
# 2021-02-26 17:23:49 pos ratio: 0.1, neg ratio: 0.5
# 2021-02-26 17:23:49 train_pose: False, train_ret: True
# 2021-02-26 17:23:49 resume: ./ckpts/cat_table_ret_conv_fc
# 2021-02-26 17:23:49 pretrain:
# 2021-02-26 17:23:49 CatId: 04379243
# 2021-02-26 17:23:49 pos ratio: 0.1 neg ratio: 0.5
# 100%|██████████████████████████████████████| 1679/1679 [00:01<00:00, 850.46it/s]
# 1569
# 1559
# 1557
# 2021-02-26 17:23:51 Finish Loading
# 2021-02-26 17:23:53 Using optimizer SGD
# 2021-02-26 17:23:53 loading checkpoint from ./ckpts/cat_table_ret_conv_fc
# start eval
# ...

# %%
# !python evaluation.py \
                      --log_name evallog \
                      --ckpt_name evallog \
                      --dataset CategoryDataset \
                      --root /scannet/ShapeNetCore.v2.PC15k \
                      --resume ./ckpts/cat_pose_id_01_FCGF16 \
                      --trainer RetrievalTrainer \
                      --embedding identity \
                      --dim 1024 512 256 \
                      --voxel_size 0.03 \
                      --catid 03001627 \
                      --batch_size 32 \
                      --model_n_out 16 \
                      --conv1_kernel_size 3 \
                      --pos_ratio 0.10 \
                      --neg_ratio 0.50 \
                      --train_pose \
                      --mode test
# Out:
# False
# 2021-02-26 20:02:28 cuda
# 2021-02-26 20:02:28 trainer: RetrievalTrainer
# 2021-02-26 20:02:28 mode: test
# 2021-02-26 20:02:28 category ID: 03001627
# 2021-02-26 20:02:28 dataset: CategoryDataset, batch_size: 32
# 2021-02-26 20:02:28 embedding dim: [1024, 512, 256]
# 2021-02-26 20:02:28 voxel size: 0.03
# 2021-02-26 20:02:28 optimizer: SGD learning rate: 0.1, exp_gamma: 0.99
# 2021-02-26 20:02:28 embedding: identity
# 2021-02-26 20:02:28 pos ratio: 0.1, neg ratio: 0.5
# 2021-02-26 20:02:28 train_pose: True, train_ret: False
# 2021-02-26 20:02:28 resume: ./ckpts/cat_pose_id_01_FCGF16
# 2021-02-26 20:02:28 pretrain:
# 2021-02-26 20:02:28 CatId: 03001627
# 2021-02-26 20:02:28 pos ratio: 0.1 neg ratio: 0.5
# 100%|███████████████████████████████████████| 1317/1317 [00:15<00:00, 85.32it/s]
# 1245
# 1242
# 2021-02-26 20:02:44 Finish Loading
# 2021-02-26 20:02:46 Using optimizer SGD
# 2021-02-26 20:02:46 loading checkpoint from ./ckpts/cat_pose_id_01_FCGF16
# start eval
# ...

# %%
# !python evaluation.py \
                      --log_name evallog \
                      --ckpt_name evallog \
                      --dataset CategoryDataset \
                      --root /scannet/ShapeNetCore.v2.PC15k \
                      --resume ./ckpts/cat_ret_conv1max_01_FCGFus \
                      --trainer RetrievalTrainer \
                      --embedding conv1_max_embedding \
                      --dim 1024 512 256 \
                      --voxel_size 0.03 \
                      --catid 03001627 \
                      --batch_size 32 \
                      --model_n_out 16 \
                      --conv1_kernel_size 3 \
                      --pos_ratio 0.10 \
                      --neg_ratio 0.50 \
                      --train_ret \
                      --mode test
# Out:
# False
# 2021-02-26 16:58:52 cuda
# 2021-02-26 16:58:52 trainer: RetrievalTrainer
# 2021-02-26 16:58:52 mode: test
# 2021-02-26 16:58:52 category ID: 03001627
# 2021-02-26 16:58:52 dataset: CategoryDataset, batch_size: 32
# 2021-02-26 16:58:52 embedding dim: [1024, 512, 256]
# 2021-02-26 16:58:52 voxel size: 0.03
# 2021-02-26 16:58:52 optimizer: SGD learning rate: 0.1, exp_gamma: 0.99
# 2021-02-26 16:58:52 embedding: conv1_max_embedding
# 2021-02-26 16:58:52 pos ratio: 0.1, neg ratio: 0.5
# 2021-02-26 16:58:52 train_pose: False, train_ret: True
# 2021-02-26 16:58:52 resume: ./ckpts/cat_ret_conv1max_01_FCGFus
# 2021-02-26 16:58:52 pretrain:
# 2021-02-26 16:58:52 CatId: 03001627
# 2021-02-26 16:58:52 pos ratio: 0.1 neg ratio: 0.5
# 100%|██████████████████████████████████████| 1317/1317 [00:12<00:00, 106.35it/s]
# 1245
# 1242
# 2021-02-26 16:59:05 Finish Loading
# 2021-02-26 16:59:08 Using optimizer SGD
# 2021-02-26 16:59:08 loading checkpoint from ./ckpts/cat_ret_conv1max_01_FCGFus
# ...

# %%
# !python evaluation.py \
                      --log_name evallog \
                      --ckpt_name evallog \
                      --dataset CategoryDataset \
                      --root /scannet/ShapeNetCore.v2.PC15k \
                      --resume ./ckpts/conv_fc_chamfer_model \
                      --trainer RetrievalTrainer \
                      --embedding conv1_fc \
                      --dim 1024 512 256 \
                      --voxel_size 0.03 \
                      --catid 03001627 \
                      --batch_size 32 \
                      --model_n_out 16 \
                      --conv1_kernel_size 3 \
                      --pos_ratio 0.10 \
                      --neg_ratio 0.50 \
                      --train_ret \
                      --mode test
# Out:
# False
# 2021-02-26 17:03:30 cuda
# 2021-02-26 17:03:30 trainer: RetrievalTrainer
# 2021-02-26 17:03:30 mode: test
# 2021-02-26 17:03:30 category ID: 03001627
# 2021-02-26 17:03:30 dataset: CategoryDataset, batch_size: 32
# 2021-02-26 17:03:30 embedding dim: [1024, 512, 256]
# 2021-02-26 17:03:30 voxel size: 0.03
# 2021-02-26 17:03:30 optimizer: SGD learning rate: 0.1, exp_gamma: 0.99
# 2021-02-26 17:03:30 embedding: conv1_fc
# 2021-02-26 17:03:30 pos ratio: 0.1, neg ratio: 0.5
# 2021-02-26 17:03:30 train_pose: False, train_ret: True
# 2021-02-26 17:03:30 resume: ./ckpts/conv_fc_chamfer_model
# 2021-02-26 17:03:30 pretrain:
# 2021-02-26 17:03:30 CatId: 03001627
# 2021-02-26 17:03:30 pos ratio: 0.1 neg ratio: 0.5
# 100%|██████████████████████████████████████| 1317/1317 [00:01<00:00, 848.27it/s]
# 1245
# 1242
# 2021-02-26 17:03:32 Finish Loading
# 2021-02-26 17:03:34 Using optimizer SGD
# 2021-02-26 17:03:34 loading checkpoint from ./ckpts/conv_fc_chamfer_model
# start eval
# ...

# %%
# !python evaluation.py \
                      --log_name evallog \
                      --ckpt_name evallog \
                      --dataset ScannetDataset \
                      --root /scannet/ShapeNetCore.v2.PC15k \
                      --scan2cad_root /scannet/crop_scan2cad_filter/data \
                      --annotation_dir /scannet/scan2cad_download_link \
                      --resume ./ckpts/scannet_ret_max_sim0_Best \
                      --trainer ScannetTrainer \
                      --embedding conv1_max_embedding \
                      --dim 1024 512 256 \
                      --voxel_size 0.03 \
                      --catid 03001627 \
                      --batch_size 32 \
                      --model_n_out 16 \
                      --conv1_kernel_size 3 \
                      --pos_ratio 0 \
                      --neg_ratio 0.50 \
                      --mode val \
                      --use_symmetry \
                      --preload False
# Out:
# 2021-02-16 04:33:28 cuda
# 2021-02-16 04:33:28 trainer: ScannetTrainer
# 2021-02-16 04:33:28 mode: val
# 2021-02-16 04:33:28 category ID: 03001627
# 2021-02-16 04:33:28 dataset: ScannetDataset, batch_size: 32
# 2021-02-16 04:33:28 embedding dim: [1024, 512, 256]
# 2021-02-16 04:33:28 voxel size: 0.03
# 2021-02-16 04:33:28 optimizer: SGD learning rate: 0.1, exp_gamma: 0.99
# 2021-02-16 04:33:28 embedding: conv1_max_embedding
# 2021-02-16 04:33:28 pos ratio: 0.0, neg ratio: 0.5
# 2021-02-16 04:33:28 train_pose: False, train_ret: False
# 2021-02-16 04:33:28 resume: ./ckpts/scannet_ret_max_sim0_Best
# 2021-02-16 04:33:28 pretrain:
# 0.03
# Loading Shapenet CAD models
# 2021-02-16 04:33:42 Using CAD Lib size: 652
# Loading Scannet scans
# Loading Scannet scans
# Loading Scannet scans
